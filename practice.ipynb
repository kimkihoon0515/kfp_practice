# %%
# Out:
# {'next_page_token': None,
#  'pipelines': [{'created_at': datetime.datetime(2022, 12, 24, 14, 53, 56, tzinfo=tzutc()),
#                 'default_version': {'code_source_url': None,
#                                     'created_at': datetime.datetime(2022, 12, 24, 14, 53, 56, tzinfo=tzutc()),
#                                     'description': None,
#                                     'id': 'bdd0f4b7-6c1a-469b-bd36-9a4a5773084c',
#                                     'name': '[Demo] XGBoost - Iterative model '
#                                             'training',
#                                     'package_url': None,
#                                     'parameters': None,
#                                     'resource_references': [{'key': {'id': 'bdd0f4b7-6c1a-469b-bd36-9a4a5773084c',
#                                                                      'type': 'PIPELINE'},
#                                                              'name': None,
# ...

# %%
# Out:
# {'next_page_token': None, 'pipelines': None, 'total_size': None}
